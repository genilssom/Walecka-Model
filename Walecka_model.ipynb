# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
from functions.constants import *
from functions.arrays import *
from functions.constant_couplings import *
from functions.solved_equations import *

# %%
plt.plot(nB, m_Ns, 'k', linewidth=1)
plt.plot(nB, m_Nsapp, 'k--', linewidth=1)
plt.xlabel('$n_{B}[fm^{-3}]$', fontsize=12)
plt.ylabel('$m^{*}_{N}/m_{N}$', fontsize=12)
plt.xlim(0,1.5)
plt.ylim(0,1.1)
plt.savefig("plots/Density-dependent effective nucleon mass.png")
plt.show()

# %%
plt.plot(n0, E0, 'k', linewidth=1)
plt.plot(nBmin/nb_sat, Emin, 'k-o')
plt.xlabel('$n_{B}/n_{0}\;\;[fm^{-3}]$', fontsize=12)
plt.ylabel('$\epsilon/n_{B}-m_{N}\;\;[MeV]$', fontsize=12)
plt.xlim(0,2.5)
plt.ylim(-22,50)
plt.annotate("saturation", (nBmin/nb_sat, -15.8), xytext=(0.87, 0),
            arrowprops={'arrowstyle':'->'})
plt.savefig("plots/Binding energy.png")
plt.show()
